# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/Machine_Learning/blob/main/ML_Chap_10_Genetic_Algorithm_Password_break.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 코드 출처: https://tasddc.tistory.com/104
# [ Genetic Algorithm ] 유전 알고리즘을 통해 비밀번호를 뚫어보자!

import random
import string

# %%
def generate_word(length):
    result = ""
    x = "".join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# %%
print(generate_word(length=10)) # 길이가 10인 임의의 문자열 생성
# Out:
# DBpUH6loFf

# %%
# 첫번째 세대가 태어남.
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))

    return population

# %%
# 최소길이가 2이고 최대길이가 10인 문자열을 100개 생성
min_len = 2
max_len = 10
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
print(pop)
# Out:
# ['5B', 'tD7', 'jcFD', 'ZYUTH', 'zkYbKy', '42RMdLK', 'ncyQKaiD', 'Oxd8HgNar', 'GYMTC6XLtN', '6t', 'mHW', '8Dr3', 'DClw6', 'sRa4XW', 'tR2Txsp', 'Eo9s4zlN', '0ME1bwX49', 'wOTLNUYvZd', '4N', '6gf', 'zmC8', 'aDCV6', 'Bjsc3G', 'NImQWp4', 'XIR9s14V', '2nXLDSkHx', '4SFL5BeE02', 'yG', 'V5z', 'Hw2v', 'c5qCn', 'ON2EMw', 'HjKzDZ5', 'aGMHiKsz', 'CNjnLbuzG', 'HXFLVt3oy6', 'FT', 'FZN', 'lKCm', 'XeWQp', 'fNRmP6', 'Mqs2UTX', 'Qjo0NzYf', 'zhaU1Snob', 'WLlT4FMZSj', '5j', 'Ry9', 'a6ct', 'TFsQn', '8yjMB9', 'uaH4glY', 'IAF1ucTx', 'K2LprjYtB', 'iFePztlf67', 'Ya', 'dyx', 'a0NO', '5WX1m', '4r7LSv', '67AtapM', 'EMvY8LJc', 'mnCM3EGpr', 'GtSOyM4BL5', 'eG', 'vCf', 'QzrF', 'tiLNn', 'qP1CXN', 'PrtTIK3', 'dBzwI3oc', 'nvkOwlh6t', 'kWFgxqaUr0', 'NQ', '0id', 'xFBI', 'QJu5T', 'R9uEB2', 'R5gGm1E', 'Ydwq2Jek', 'cXTNOFAyI', 'Ta6UyMz05B', 'OB', 'vM8', 'mtw2', 'ns875', 'BuR3ol', '17QLOMq', 'gj0OsVet', 'kEQPC5eyn', 'Qira3COKgm', 'Ow', 'yCA', 'S7Yb', 'yizpC', 'GbFsmP', 'DjoYhbG', 'UcEZtauJ', 'BHGX4i6aT', 'M0CtvP4mIj', 'dX']

# %%
# fitness 측정 (성능 측정 단계)
def fitness(password, test_word):
    score = 0 # 초기 점수는 0점으로 초기화.

    # 길이가 다르면 0점 return
    if len(password) != len(test_word):
        return score

    # 길이가 같으면 0.5점을 더해준다.
    len_score = 0.5
    score += len_score

    # 설정한 비밀번호와 비교하여 해당 문자열이 있는지 있으면 1점을 더해준다.
    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점인지 계산한다. (성능 측정)
    return score / (len(password) + len_score) * 100

# %%
print(fitness('abcdE', 'abcde')) # 설정한 비밀번호와 비교하였을 때 점수는 81.81점)
# Out:
# 81.81818181818183

# %%
def compute_performance(population, password):
    performance_list = [] # population을 점수 순서대로 정렬하기 위해서 list 생성.
    for individual in population:
        # 각각의 자식들의 점수를 측정한다.
        score = fitness(password, individual)

        # 비밀번호의 길이를 예측할 수 있다.
        if score > 0: # 점수가 0보다 크다는 뜻은 비밀번호의 길이는 맞췄다는 의미이다.
            pred_len = len(individual) # 예상 길이를 pred_len 변수에 저장한다.
        performance_list.append([individual, score])

    # list를 정렬하는데 key(점수)를 기준으로 내림차순으로 정렬한다.
    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

# %%
# 살아남은 아이들을 select할 함수이다.
def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    # best_sample 수 만큼 뽑아서 다음 세대로 보낸다.
    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    # 랜덤으로 운이 좋은 자식들을 살린다.
    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for I in lucky_survivors:
        next_generation.append(I[0])

    # 다음 세대의 아이들의 수가 부족할 수 있기 때문에 랜덤으로 생성하여 채워넣는 부분이다.
    if len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    # 다음 세대의 아이들 리스트를 랜덤한 순으로 섞는다.
    random.shuffle(next_generation)
    return next_generation

# %%
password = generate_word(length=10) # 길이가 10인 임의의 문자열 생성
print("password is ", password)
# 최소길이가 2이고 최대길이가 10인 문자열을 100개 생성
min_len = 2
max_len = 10
pop = generate_population(size=100, min_len=min_len, max_len=max_len)

pop_sorted, pred_len = compute_performance(pop, password)
print(pop_sorted)
# 100명의 자식들 중에서 성능이 우수한 20명과 운이 좋은 20명을 선발한다.
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('password length must be %s' % pred_len)
print(survivors)
# Out:
# password is  o1F30rwJmR
# [['H14zv8Qb5r', 14.285714285714285], ['3Xv4sVOhrL', 4.761904761904762], ['u3GK6QYN1l', 4.761904761904762], ['SbToVJFLnv', 4.761904761904762], ['OiPYfVW5pj', 4.761904761904762], ['FNUTnHWao9', 4.761904761904762], ['R4V7iDxFMa', 4.761904761904762], ['aReGVntHC1', 4.761904761904762], ['XWlpPAU0LM', 4.761904761904762], ['MNdPAC9DEj', 4.761904761904762], ['Qm3qUTDvNe', 4.761904761904762], ['5g', 0], ['1ve', 0], ['7aNf', 0], ['xhVGI', 0], ['K4SpFd', 0], ['xGefE5W', 0], ['EjqI9wUV', 0], ['fBsznLxTS', 0], ['s2', 0], ['0Ok', 0], ['nRCw', 0], ['UVlMN', 0], ['WASgFo', 0], ['XknUgFf', 0], ['g2XcR3vU', 0], ['6PeqV5OD8', 0], ['Xi', 0], ['1CY', 0], ['Krwb', 0], ['4PWQG', 0], ['KAkt5b', 0], ['kgXKO8s', 0], ['xAloqkbp', 0], ['54WiKbJzM', 0], ['3W', 0], ['mry', 0], ['O69H', 0], ['IA6dt', 0], ['3Qe48T', 0], ['k8TpAEh', 0], ['6YrtL2S8', 0], ['7hLuEg0yQ', 0], ['uq', 0], ['Bhx', 0], ['iWOm', 0], ['uC3HV', 0], ['z3nlyH', 0], ['mUCAV2f', 0], ['NeDFMcp8', 0], ['FP3gSn9MC', 0], ['R2', 0], ['jTl', 0], ['UvhE', 0], ['WOAY1', 0], ['daNyC7', 0], ['2xN5mW3', 0], ['5Yrlb9Pm', 0], ['cI0AqmOwH', 0], ['HZ', 0], ['0FI', 0], ['W54O', 0], ['zHJsW', 0], ['g3sMz7', 0], ['KIlD9u0', 0], ['xwRSUsKM', 0], ['ByOmTLrKf', 0], ['QB', 0], ['isT', 0], ['k46L', 0], ['Xnkw2', 0], ['prL53G', 0], ['kuWdejq', 0], ['fpWl1u6t', 0], ['ShW9yNZ3X', 0], ['aD', 0], ['Xia', 0], ['B9ML', 0], ['WIimr', 0], ['kKpmAN', 0], ['rqTcpOg', 0], ['xy5vXcmu', 0], ['Ft8fga5oW', 0], ['ry', 0], ['QeX', 0], ['HOG5', 0], ['h40Pq', 0], ['9roQFS', 0], ['JWRu3aS', 0], ['GjYABzpa', 0], ['wE3mTj8Ak', 0], ['O6', 0], ['RuZ', 0], ['t1Do', 0], ['MS8lv', 0], ['XG0361', 0], ['6sq4jod', 0], ['vnVzimds', 0], ['KMYAugt81', 0], ['zH', 0]]
# password length must be 10
# ['cI0AqmOwH', 'uq', 'g3sMz7', 'OiPYfVW5pj', 'ByOmTLrKf', '6YrtL2S8', 'K4SpFd', '5g', 'XWlpPAU0LM', '3Xv4sVOhrL', 'Qm3qUTDvNe', 'H14zv8Qb5r', 'vnVzimds', 'h40Pq', 'mry', 'aReGVntHC1', 'POob6L18Sy', 'u3GK6QYN1l', 'MNdPAC9DEj', 'FNUTnHWao9', 'Xi', '1CY', 'isT', 'SbToVJFLnv', 'kgXKO8s', 'Qm3qUTDvNe', 'JWRu3aS', 'O69H', 'MNdPAC9DEj', 'SbToVJFLnv', 'R4V7iDxFMa', '3Qe48T']

# %%
# Create Children (살아남은 아이들을 교배시킨다.)
# individual1 : 엄마
# individual2 : 아빠
def create_child(individual1, individual2):
    child = ''
    # 더 짧은 길이의 유전자에 맞춰서 생성.
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100*random.random()) < 50): # 50#의 확률로 엄마의 유전자를 획득
            child += individual1[i]
        else:
            child += individual2[i] # 나머지 50# 확률로 아빠의 유전자를 획득
    return child

def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) -1 -i]))
    return next_population

# %%
# survivors : 성능이 좋은아이들 20명, 운이좋은 아이들 20명 이므로 길이는 40
# 살아남은 아이들이 각각 5명씩 아이를 낳는다.
# 40명의 부모 = 20커플
# 5명씩 아이를 낳으면 20 X 5 = 100명
children = create_children(survivors, 5)
print("---------------children---------------\n", children)
# Out:
# ---------------children---------------
#  ['3Q048T', '3Qe48T', 'cI048T', 'cIe48m', '3Ie4qT', 'Rq', 'R4', 'u4', 'Rq', 'Rq', 'gbToVJ', 'gbTMzJ', 'S3sMV7', 'g3ToVJ', 'SbTMV7', 'ONdYAVW5pj', 'ONdYAC9DEj', 'ONPPfC9Dpj', 'OidPfC95pj', 'ONPPAVWDEj', 'O6OH', 'O6Om', 'By9H', 'O69m', 'B6Om', 'JWruLaS', 'JYruLaS', '6WRu3aS', 'JWrtL2S', 'JWRu3aS', 'Q4SpUT', 'Q4SpFT', 'Qm3qFd', 'Q43qFT', 'Q4SqUT', '5g', 'kg', '5g', '5g', 'kg', 'SWlpVAULnv', 'XbToVAU0nv', 'SbloVJFLLv', 'SWTpVJU0LM', 'SWlpVJU0nv', '3XT', 'iXT', 'iXT', '3sv', '3sv', 'QmY', '1CY', 'QC3', 'QC3', '1C3', 'Hi', 'Xi', 'H1', 'Hi', 'Hi', 'FNVznmWa', 'vnVziHds', 'vNUTnmWa', 'vnVznHWs', 'vNVTnHda', 'h40Pq', 'h40PA', 'h40Pq', 'h40Pq', 'MNdPA', 'mry', 'urG', 'u3G', 'urG', 'u3G', 'aRebVL18C1', 'PRoGVn18Cy', 'aReb6L18Sy', 'aRob6Lt8Sy', 'aOobVLtHS1']

# %%
# 돌연변이 생성
def mutate_word(word):
    # 비밀번호에서 임의의 idx 값을 추출한다
    idx = int (random.random() * len(word))

    # 추출한 idx 값에 랜덤한 값을 넣는다.
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

# 100명의 아이들 중에서 10# 확률로 돌연변이를 생성한다.
def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

# %%
# 비밀번호의 최대, 최소 자릿수를 지정해놓음.
password = 'T4As2Dc39i12AFHD'
min_len = 2
max_len = 20
n_generation = 1000
population = 100
best_sample = 20
lucky_few = 20
n_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

# 총 300 세대를 생성하면서 반복한다.
for g in range(n_generation):

    pop_sorted, pred_len = compute_performance(population=pop, password=password)

    # pop_sorted에서 첫 번째의 점수가 100점이면 비밀번호 찾음.
    if int(pop_sorted[0][1]) == 100:
        print("SUCCESS! The password is %s" % (pop_sorted[0][0]))
        break

    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)

    children = create_children(parents=survivors, n_child=n_child)

    new_generation = mutate_population(population=children, chance_of_mutation=chance_of_mutation)

    pop = new_generation

    print("===========%sth generation==========" %(g+1))
    print(pop_sorted[0])
# Out:
# ===========1th generation==========
# ['pv9oJWF4zryldBu3', 3.0303030303030303]
# ===========2th generation==========
# ['xos41ChFPz5bL7zA', 3.0303030303030303]
# ===========3th generation==========
# ['xos41ChFPz5bL7zA', 3.0303030303030303]
# ===========4th generation==========
# ['xos41ChFPz5bL7zA', 3.0303030303030303]
# ===========5th generation==========
# ['xos41ChFPz5bL7zA', 3.0303030303030303]
# ===========6th generation==========
# ['xos41ChFP65bL7zA', 3.0303030303030303]
# ===========7th generation==========
# ['wos41CpFPz5bL7zj', 3.0303030303030303]
# ===========8th generation==========
# ['xosk1ChFPz5bL7zA', 3.0303030303030303]
# ===========9th generation==========
# ['xos4xChFPz5bL7zA', 3.0303030303030303]
# ===========10th generation==========
# ['wasx1DhFPz5bL7zj', 9.090909090909092]
# ===========11th generation==========
# ['Xos41DpFPz5bL7zj', 9.090909090909092]
# ===========12th generation==========
# ['wasx1DpFPz5bL7Mj', 9.090909090909092]
# ===========13th generation==========
# ['x0skxDhFPzRbL7zA', 9.090909090909092]
# ===========14th generation==========
# ['Xosk1DhF5z5bL7zA', 9.090909090909092]
# ===========15th generation==========
# ['Xosk1DpFPz5iL7zA', 9.090909090909092]
# ===========16th generation==========
# ['Xosx1DhFPMRbk7zA', 9.090909090909092]
# ===========17th generation==========
# ['Xosx1DhFPzRbL7zj', 9.090909090909092]
# ===========18th generation==========
# ['xosk1DhFPz5iL7zA', 9.090909090909092]
# ===========19th generation==========
# ['Xosx1DhFPz5bL7zA', 9.090909090909092]
# ===========20th generation==========
# ['Xosk1DhFPz8bL7zr', 9.090909090909092]
# ===========21th generation==========
# ['XJsx1DhFPz8bL7zA', 9.090909090909092]
# ===========22th generation==========
# ['XJsx1DpFPz5bL7zA', 9.090909090909092]
# ===========23th generation==========
# ['XJsk1DpFPz5iL7zA', 9.090909090909092]
# ===========24th generation==========
# ['Xosx1DhFPzRiL7tA', 9.090909090909092]
# ===========25th generation==========
# ['Xosx1DpF5M5iL7zA', 9.090909090909092]
# ===========26th generation==========
# ['Xosk1DpF5M5iL7zA', 9.090909090909092]
# ===========27th generation==========
# ['Xosx1DpFuzRiL7zA', 9.090909090909092]
# ===========28th generation==========
# ['Xosx1DpFuzRiL7zA', 9.090909090909092]
# ===========29th generation==========
# ['Xosx1DpFuzg2L7zA', 15.151515151515152]
# ===========30th generation==========
# ['Xosk1DpFuzg2L0zA', 15.151515151515152]
# ===========31th generation==========
# ['Xosx1DpF5zz2L0zA', 15.151515151515152]
# ===========32th generation==========
# ['Xosv1DpFPzR267zB', 15.151515151515152]
# ===========33th generation==========
# ['Xosx1DpFPzR260zA', 15.151515151515152]
# ===========34th generation==========
# ['Xosk1DpFPzR2h7zA', 15.151515151515152]
# ===========35th generation==========
# ['Xosx1DpF5zR2L7zA', 15.151515151515152]
# ===========36th generation==========
# ['Xosx1DpFPzR2L7zA', 15.151515151515152]
# ===========37th generation==========
# ['XoXx1DpFPzR2L7zA', 15.151515151515152]
# ===========38th generation==========
# ['XoXx1DpFPzR2L0zA', 15.151515151515152]
# ===========39th generation==========
# ['BoXxmDpF5zR2h0zA', 15.151515151515152]
# ===========40th generation==========
# ['XoXxmDpF52R2h0zA', 15.151515151515152]
# ===========41th generation==========
# ['Mosx1DpFPzR2h0zA', 15.151515151515152]
# ===========42th generation==========
# ['XoGx1DpFPrR2L7zA', 15.151515151515152]
# ===========43th generation==========
# ['Tosx1DpFPzR2L0zA', 21.21212121212121]
# ===========44th generation==========
# ['Moss1DpFPzR2h7zA', 21.21212121212121]
# ===========45th generation==========
# ['Moss1DpFPzR2L0zK', 21.21212121212121]
# ===========46th generation==========
# ['Toss1DpFPzR2L0zA', 27.27272727272727]
# ===========47th generation==========
# ['ToXs1DpFPzR2L0zK', 27.27272727272727]
# ===========48th generation==========
# ['ToXs1DpFPzR2L7zK', 27.27272727272727]
# ===========49th generation==========
# ['ToXs1DpFPzR2L0zK', 27.27272727272727]
# ===========50th generation==========
# ['ToXs1DaFPzR2L7zA', 27.27272727272727]
# ===========51th generation==========
# ['ToXs1DaFPzR2L7zA', 27.27272727272727]
# ===========52th generation==========
# ['ToXs1DpFPzR2L7zA', 27.27272727272727]
# ===========53th generation==========
# ['ToXs1DaFPzR2L7zA', 27.27272727272727]
# ===========54th generation==========
# ['ToXs1DpF5zR2L0zA', 27.27272727272727]
# ===========55th generation==========
# ['TPXs1DpFPzR2L0zt', 27.27272727272727]
# ===========56th generation==========
# ['ToXs1DpFPrR2L7zK', 27.27272727272727]
# ===========57th generation==========
# ['TPXs1DpFPzR2L8zA', 27.27272727272727]
# ===========58th generation==========
# ['TmXs1DpFkzR2L7zK', 27.27272727272727]
# ===========59th generation==========
# ['Toss1DpFPzR2L7zA', 27.27272727272727]
# ===========60th generation==========
# ['TPXs1DpFPzR2LdzA', 27.27272727272727]
# ===========61th generation==========
# ['ToXs1DaFPzR2L0zt', 27.27272727272727]
# ===========62th generation==========
# ['Toss1DpFPzR2L7zA', 27.27272727272727]
# ===========63th generation==========
# ['TPss1DaFPzR2L7zA', 27.27272727272727]
# ===========64th generation==========
# ['TPXs1DaFPzR2L7zA', 27.27272727272727]
# ===========65th generation==========
# ['Toss1DpFPzR2L7zA', 27.27272727272727]
# ===========66th generation==========
# ['TPXs1DpFPzR2L7zA', 27.27272727272727]
# ===========67th generation==========
# ['Toms1DaFPzR2L7nA', 27.27272727272727]
# ===========68th generation==========
# ['ToXscDaFPzR2L7zA', 27.27272727272727]
# ===========69th generation==========
# ['TPss1DpFPzR2L7zA', 27.27272727272727]
# ===========70th generation==========
# ['TPXs1DpFPzR2LdzA', 27.27272727272727]
# ===========71th generation==========
# ['ToXs1DpFPzR2LdzA', 27.27272727272727]
# ===========72th generation==========
# ['TPss1DaTPzR2LdzA', 27.27272727272727]
# ===========73th generation==========
# ['Toss1DaFPzR2LdzA', 27.27272727272727]
# ===========74th generation==========
# ['Toss1DaFPzR2LdzA', 27.27272727272727]
# ===========75th generation==========
# ['Toss1DpFPzR2LdzA', 27.27272727272727]
# ===========76th generation==========
# ['TPXs1DaFPzR2LdzA', 27.27272727272727]
# ===========77th generation==========
# ['ToXs1DZFPzR2LdzA', 27.27272727272727]
# ===========78th generation==========
# ['Toss1DZF9zR2LdzA', 33.33333333333333]
# ===========79th generation==========
# ['Toss1DZF9zR2LdzA', 33.33333333333333]
# ===========80th generation==========
# ['Toss1DZF9zR2LdzA', 33.33333333333333]
# ===========81th generation==========
# ['ToXs1DZF9zR2LdzA', 33.33333333333333]
# ===========82th generation==========
# ['ToXs1DZF9zk2LdzA', 33.33333333333333]
# ===========83th generation==========
# ['Toss1DZF9zR2LdzA', 33.33333333333333]
# ===========84th generation==========
# ['TAXs1DZF9zR2LdzA', 33.33333333333333]
# ===========85th generation==========
# ['ToXs1DZF9zR2LFzA', 39.39393939393939]
# ===========86th generation==========
# ['ToXs1DZF9zR2LFzA', 39.39393939393939]
# ===========87th generation==========
# ['TVXs1DZF9zR2LFzA', 39.39393939393939]
# ===========88th generation==========
# ['TVss1DZF9zo2LFzA', 39.39393939393939]
# ===========89th generation==========
# ['ToXs1DZF9zR2LFzA', 39.39393939393939]
# ===========90th generation==========
# ['TVss1DNF9zo2LFzD', 45.45454545454545]
# ===========91th generation==========
# ['Toss1DZF9to2LFzD', 45.45454545454545]
# ===========92th generation==========
# ['ToXs1DNF9to2LFzD', 45.45454545454545]
# ===========93th generation==========
# ['TVXs1DNR9zR2LFzD', 45.45454545454545]
# ===========94th generation==========
# ['ToXs1DNF9zo2LFzD', 45.45454545454545]
# ===========95th generation==========
# ['Toss1DZF9zo2LFzD', 45.45454545454545]
# ===========96th generation==========
# ['Toss1DZR9zo2LFzD', 45.45454545454545]
# ===========97th generation==========
# ['Toss1DZF9zo2LFzD', 45.45454545454545]
# ===========98th generation==========
# ['TVss1DZF9zo2LFzD', 45.45454545454545]
# ===========99th generation==========
# ['Toss1DZF9zo2LFzD', 45.45454545454545]
# ===========100th generation==========
# ['Toss1DZF9zo2LFzD', 45.45454545454545]
# ===========101th generation==========
# ['Toss1DZF9zo2LFzD', 45.45454545454545]
# ===========102th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========103th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========104th generation==========
# ['ToXs1DZF9z12LFzD', 51.515151515151516]
# ===========105th generation==========
# ['TVss1DZF9z12LFzD', 51.515151515151516]
# ===========106th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========107th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========108th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========109th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========110th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========111th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========112th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========113th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========114th generation==========
# ['Toss1DZF9z12WFzD', 51.515151515151516]
# ===========115th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========116th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========117th generation==========
# ['Toss1DZF9z12WFzD', 51.515151515151516]
# ===========118th generation==========
# ['Toss1DZF9z12LFzD', 51.515151515151516]
# ===========119th generation==========
# ['Toss1DZF9A12WFzD', 51.515151515151516]
# ===========120th generation==========
# ['Toss1DZF9z12WF5D', 51.515151515151516]
# ===========121th generation==========
# ['Toss1DZF9A12WFzD', 51.515151515151516]
# ===========122th generation==========
# ['Toss1DZF9A12WFzD', 51.515151515151516]
# ===========123th generation==========
# ['TIss1DZF9A12rF5D', 51.515151515151516]
# ===========124th generation==========
# ['Toss1DZF9z12WFzD', 51.515151515151516]
# ===========125th generation==========
# ['TIss1DZF9A12LFzD', 51.515151515151516]
# ===========126th generation==========
# ['Toss1DZF9A12LFED', 51.515151515151516]
# ===========127th generation==========
# ['Toss1DZF9A12FFED', 51.515151515151516]
# ===========128th generation==========
# ['Toss1DZF9A12WFzD', 51.515151515151516]
# ===========129th generation==========
# ['Toss1DZF9N12WFzD', 51.515151515151516]
# ===========130th generation==========
# ['Toss1DZF9N12WFzD', 51.515151515151516]
# ===========131th generation==========
# ['Toss1DZF9z12rFzD', 51.515151515151516]
# ===========132th generation==========
# ['Toss1DZF9N12WFzD', 51.515151515151516]
# ===========133th generation==========
# ['Trss1DiF9A12AFzD', 57.57575757575758]
# ===========134th generation==========
# ['TIss1DiF9A12AFzD', 57.57575757575758]
# ===========135th generation==========
# ['Trss1DZF9z12AFzD', 57.57575757575758]
# ===========136th generation==========
# ['Trss1DZF9z12AF5D', 57.57575757575758]
# ===========137th generation==========
# ['TIss1DzF9z12AFzD', 57.57575757575758]
# ===========138th generation==========
# ['TIss1DZF9A12AFzD', 57.57575757575758]
# ===========139th generation==========
# ['Toss1DZF9A12AFzD', 57.57575757575758]
# ===========140th generation==========
# ['Toss1DZF9i12AFzD', 63.63636363636363]
# ===========141th generation==========
# ['TIss1DZ39A12AFzD', 63.63636363636363]
# ===========142th generation==========
# ['TIss1DZ39z12AFzD', 63.63636363636363]
# ===========143th generation==========
# ['TIss1DcF9i12AFzD', 69.6969696969697]
# ===========144th generation==========
# ['TIss1DZ39i12AFxD', 69.6969696969697]
# ===========145th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========146th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========147th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========148th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========149th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========150th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========151th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========152th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========153th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========154th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========155th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========156th generation==========
# ['TIss1Dc39i12AFzD', 75.75757575757575]
# ===========157th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========158th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========159th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========160th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========161th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========162th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========163th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========164th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========165th generation==========
# ['Toss1Dc39i12AFzD', 75.75757575757575]
# ===========166th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========167th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========168th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========169th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========170th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========171th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========172th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========173th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========174th generation==========
# ['TVAs1Dc39i12AFzD', 81.81818181818183]
# ===========175th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========176th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========177th generation==========
# ['ToAsgDc39i12AFzD', 81.81818181818183]
# ===========178th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========179th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========180th generation==========
# ['ToAsvDc39i12AFzD', 81.81818181818183]
# ===========181th generation==========
# ['ToAsvDc39i12AF2D', 81.81818181818183]
# ===========182th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========183th generation==========
# ['ToAsvDc39i12AFzD', 81.81818181818183]
# ===========184th generation==========
# ['TBAs1Dc39i12AF2D', 81.81818181818183]
# ===========185th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========186th generation==========
# ['TBAs1Dc39i12AFzD', 81.81818181818183]
# ===========187th generation==========
# ['TVAsdDc39i12AFzD', 81.81818181818183]
# ===========188th generation==========
# ['ToAsdDc39i12AF3D', 81.81818181818183]
# ===========189th generation==========
# ['TBAs1Dc39i12AFzD', 81.81818181818183]
# ===========190th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========191th generation==========
# ['ToAsdDc39i12AFzD', 81.81818181818183]
# ===========192th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========193th generation==========
# ['TMAsdDc39i12AF2D', 81.81818181818183]
# ===========194th generation==========
# ['TMAsdDc39i12AFzD', 81.81818181818183]
# ===========195th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========196th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========197th generation==========
# ['TVAsvDc39i12AFzD', 81.81818181818183]
# ===========198th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========199th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========200th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========201th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========202th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========203th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========204th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========205th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========206th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========207th generation==========
# ['TMAs1Dc39i12AF9D', 81.81818181818183]
# ===========208th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========209th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========210th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========211th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========212th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========213th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========214th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========215th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========216th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========217th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========218th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========219th generation==========
# ['ToAs1Dc39i12AFSD', 81.81818181818183]
# ===========220th generation==========
# ['ToAs1Dc39i12AFzD', 81.81818181818183]
# ===========221th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========222th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========223th generation==========
# ['TMAs1Dc39i12AFSD', 81.81818181818183]
# ===========224th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========225th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========226th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========227th generation==========
# ['ToAs1Dc39i12AF0D', 81.81818181818183]
# ===========228th generation==========
# ['T5As7Dc39i12AF0D', 81.81818181818183]
# ===========229th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========230th generation==========
# ['TMAs1Dc39i12AF0D', 81.81818181818183]
# ===========231th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========232th generation==========
# ['TMAs1Dc39i12AFzD', 81.81818181818183]
# ===========233th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========234th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========235th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========236th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========237th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========238th generation==========
# ['TMAs2Dc39i12AFzD', 87.87878787878788]
# ===========239th generation==========
# ['TMAs2Dc39i12AFzD', 87.87878787878788]
# ===========240th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========241th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========242th generation==========
# ['TMAs2Dc39i12AFSD', 87.87878787878788]
# ===========243th generation==========
# ['TMAs2Dc39i12AFzD', 87.87878787878788]
# ===========244th generation==========
# ['TMAs2Dc39i12AFSD', 87.87878787878788]
# ===========245th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========246th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========247th generation==========
# ['TMAs2Dc39i12AFxD', 87.87878787878788]
# ===========248th generation==========
# ['TMAs2Dc39i12AFSD', 87.87878787878788]
# ===========249th generation==========
# ['TMAs2Dc39i12AFSD', 87.87878787878788]
# ===========250th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========251th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========252th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========253th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========254th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========255th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========256th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========257th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========258th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========259th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========260th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========261th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========262th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========263th generation==========
# ['TMAs2Dc39i12AFZD', 87.87878787878788]
# ===========264th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========265th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========266th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========267th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========268th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========269th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========270th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========271th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========272th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========273th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========274th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========275th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========276th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========277th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========278th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========279th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========280th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========281th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========282th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========283th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========284th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========285th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========286th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========287th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========288th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========289th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========290th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========291th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========292th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========293th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========294th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========295th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========296th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========297th generation==========
# ['TMAs2Dc39i12AFsD', 87.87878787878788]
# ===========298th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========299th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========300th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========301th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========302th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========303th generation==========
# ['T7As2Dc39i12AF0D', 87.87878787878788]
# ===========304th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========305th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========306th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========307th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========308th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========309th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========310th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========311th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========312th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========313th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========314th generation==========
# ['TMAs2Dc39i12AFjD', 87.87878787878788]
# ===========315th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========316th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========317th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========318th generation==========
# ['T2As2Dc39i12AFwD', 87.87878787878788]
# ===========319th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========320th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========321th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========322th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========323th generation==========
# ['TgAs2Dc39i12AF0D', 87.87878787878788]
# ===========324th generation==========
# ['T2As2Dc39i12AFwD', 87.87878787878788]
# ===========325th generation==========
# ['TMAs2Dc39i12AF0D', 87.87878787878788]
# ===========326th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========327th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========328th generation==========
# ['T2As2Dc39i12AFwD', 87.87878787878788]
# ===========329th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========330th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========331th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========332th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========333th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========334th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========335th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========336th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========337th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========338th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========339th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========340th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========341th generation==========
# ['T2As2Dc39i12AF0D', 87.87878787878788]
# ===========342th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========343th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========344th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========345th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========346th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========347th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========348th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========349th generation==========
# ['T4As2Dc39i12AFaD', 93.93939393939394]
# ===========350th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========351th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========352th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========353th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========354th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========355th generation==========
# ['T4As2Dc39i12AFaD', 93.93939393939394]
# ===========356th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========357th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========358th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========359th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========360th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========361th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========362th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========363th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========364th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========365th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========366th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========367th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========368th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========369th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========370th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========371th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========372th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========373th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========374th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========375th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========376th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========377th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========378th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========379th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========380th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========381th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========382th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========383th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========384th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========385th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========386th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========387th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# ===========388th generation==========
# ['T4As2Dc39i12AF0D', 93.93939393939394]
# SUCCESS! The password is T4As2Dc39i12AFHD
